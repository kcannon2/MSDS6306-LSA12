# %% [markdown]
# Practice Questions
# 1. Create a list named my_list in python with the following data points

# %%
my_list = [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]

# %% [markdown]
# a. Print the 5th element in the list

# %%
print(my_list[4])
# Out:
# 39.0

# %% [markdown]
# b. Append 55.2 to my_list

# %%
my_list.append(55.2)

# %% [markdown]
# c. Remove the 6th element in the list

# %%
print(my_list[5])
# Out:
# 60.0

# %%
my_list.remove(my_list[5])

# %%
print(my_list)
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 47.4, 41.1, 45.8, 35.6, 55.2]

# %% [markdown]
# d. Iterate over the list to print data points greater than 45

# %%
for item in my_list:
    if item > 45:
        print(item)
# Out:
# 45.4
# 47.4
# 45.8
# 55.2

# %% [markdown]
# 2. Introduction to numpy

# %% [markdown]
# a. Import the numpy library using the following command – import numpy

# %%
import numpy

# %% [markdown]
# b. Declare numpy array with the same data points as in my_list using numpy.array()

# %%
my_list2 = numpy.array([45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6])

# %% [markdown]
# c. Compute the mean and standard deviation using numpy.mean() and numpy.std() of
# the above array

# %%
numpy.mean(my_list2)
# Out:
# 43.040000000000006

# %%
numpy.std(my_list2)
# Out:
# 7.0611897014596625

# %% [markdown]
# d. Use logical referencing to get only those values that are less than 45

# %%
for item in my_list2:
    if item < 45:
        print(item)
# Out:
# 44.2
# 36.8
# 35.1
# 39.0
# 41.1
# 35.6

# %% [markdown]
# e. Compute the max and min of the array using numpy.max() and numpy.min()

# %%
numpy.max(my_list2)
# Out:
# 60.0

# %%
numpy.min(my_list2)
# Out:
# 35.100000000000001

# %% [markdown]
# 3. Introduction to pandas

# %% [markdown]
# a. Import the pandas library – import pandas

# %%
import pandas
# %pandas in line
# Out:
# ERROR:root:Line magic function `%pandas` not found.

# %% [markdown]
# b. Read the IRIS dataset into iris using pandas.read_csv()

# %%
iris = pandas.read_csv('F:\SMU\MSDS 6306\Live Session 13\LSA\Iris.csv')

# %% [markdown]
# c. Using iris.head(), display the head of the dataset

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# d. Use DataFrame.drop() to drop the id column

# %%
iris2 = iris.drop('Id', 1)

# %% [markdown]
# e. Subset dataframe to create a new data frame that includes only the measurements for the setosa species

# %%
iris_setosa = iris2[iris2.Species == 'Iris-setosa']

# %% [markdown]
# f. Use DataFrame.describe() to get the summary statistics

# %%
iris_setosa.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         5.00600      3.418000       1.464000       0.24400
# std          0.35249      0.381024       0.173511       0.10721
# min          4.30000      2.300000       1.000000       0.10000
# 25%          4.80000      3.125000       1.400000       0.20000
# 50%          5.00000      3.400000       1.500000       0.20000
# 75%          5.20000      3.675000       1.575000       0.30000
# max          5.80000      4.400000       1.900000       0.60000

# %% [markdown]
# g. Use DataFrame.plot() to plot the boxplot for all 4 numeric columns/iris measurements

# %%
import matplotlib.pyplot
# %matplotlib inline

# %%
iris_setosa.plot.box()

# %% [markdown]
# *NOTE: The assignment question does not provide correct instruction for this part.

# %% [markdown]
# h. Use DataFrame.groupby() to create grouped data frames by Species and compute
# summary statistics using DataFrame.describe()

# %%
iris_grouped = iris2.groupby('Species')

# %%
iris_grouped.describe()
# Out:
#                        PetalLengthCm  PetalWidthCm  SepalLengthCm  \
# Species
# Iris-setosa     count      50.000000     50.000000      50.000000
#                 mean        1.464000      0.244000       5.006000
#                 std         0.173511      0.107210       0.352490
#                 min         1.000000      0.100000       4.300000
#                 25%         1.400000      0.200000       4.800000
#                 50%         1.500000      0.200000       5.000000
#                 75%         1.575000      0.300000       5.200000
#                 max         1.900000      0.600000       5.800000
# Iris-versicolor count      50.000000     50.000000      50.000000
#                 mean        4.260000      1.326000       5.936000
#                 std         0.469911      0.197753       0.516171
#                 min         3.000000      1.000000       4.900000
#                 25%         4.000000      1.200000       5.600000
# ...

# %% [markdown]
# i. Use DataFrame.boxplot() to plot boxplots by Species

# %%
iris_grouped.boxplot()
# Out:
# C:\Users\KCannon\Anaconda3\lib\site-packages\pandas\tools\plotting.py:3082: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   rot=rot, grid=grid, **kwds)
# OrderedDict([('Iris-setosa',
#               {'boxes': [<matplotlib.lines.Line2D at 0x2b80b1b4e10>,
# ...
#                'caps': [<matplotlib.lines.Line2D at 0x2b80b1a3eb8>,
# ...
#                'fliers': [<matplotlib.lines.Line2D at 0x2b80b1b82e8>,
# ...
#                'means': [],
#                'medians': [<matplotlib.lines.Line2D at 0x2b80b16cb38>,
# ...
#                'whiskers': [<matplotlib.lines.Line2D at 0x2b80b1b40b8>,
# ...
#                 <matplotlib.lines.Line2D at 0x2b80b1e6cf8>]}),
#              ('Iris-versicolor',
#               {'boxes': [<matplotlib.lines.Line2D at 0x2b80b1fc9e8>,
# ...

# %% [markdown]
# j. Plot a scatter matrix plot using the seaborn library. Use the following to load and plot

# %%
import seaborn

# %%
seaborn.pairplot(iris2)

# %% [markdown]
# *NOTE: the 'by' argument does not exist in seaborn.pairplot(), so it was ignored. However, the 'hue' argument appears to plot the data by a given variable, which was the intended function. The pairplot with the 'hue' argument set to 'Species' is shown below.

# %%
seaborn.pairplot(iris2, hue='Species')
